# %%
import os
import openai

apikey_path = 'apikey.txt'#读取同文件夹目录的文件
with open(apikey_path, 'r') as f:
    key = f.read()

#连接chatgpt
openai.organization = "org-tCd0A0x7hh3O9EpDr9OiV0Or" #它用于标识具有访问权限的 OpenAI 组织，大部分情况不需要
openai.api_key = key#api访问接口


#这个方法用来发送消息
def send(model,messages):
    a=openai.ChatCompletion.create(
        model=model,
        messages=messages
    )
    
    return a.choices[0].message.content


#这个方法负责把每次的对话记录下来，并且不断循环这个过程
def chat(model):
    while True:
        messages=[]#用于保存对话历史记录，每次发出请求都要把历史记录一起发给chatgpt。聊天越久，记录就会保存的越多。
        while True:
            content = input("You: ")#用户输入的聊天内容
            if content.lower() == "bye":#如果你输入bye，那么结束对话
                 break
            messages.append({"role":"user","content":content})#将用户的发言加入到历史记录中
            answer=send(model,messages)#将机器人的发言保存在answer变量中
            #print(messages)#可以时时查看聊天历史记录的变化
            messages.append({"role":"system","content":answer})#将机器人的发言加入到历史记录中
            #print(messages)
            print("Chatbot:", answer)#将机器人的发言打印出来
        break

# %% [markdown]
# 1 商业价值

# %%
'''
更好的效果：给以一个具体的内容，而不是一大堆文章让你去阅读后了解。

为了完成以下任务，我们需要明确每个任务的输入，输出是什么。
然后再设计我们的方法论，通过一步步思考，来得到答案。



1生成：已知输入+知识，预测结果。
三段论，以假设出发，得出结论。
不同的任务，其基础假设不同，因此需要不同的预测模型。
1翻译。
2财务报表分析。
3宏观经济预测。
4历史数据相关性预测。
5商业终局战略分析。
6计算任务。
7提取核心观点，并分类总结。
8理解文章论证过程。

2归因：已知输入+输出，排查属于哪个知识。来得知关键点。
从结果出发，根据实验数据，去寻找游戏规则。
1法律咨询。
2为某技能形成教学。
3数据运营分析。
4行业市场格局分析。
5商业经营模式分析。
6产业链分析。
7心理咨询。

3创意：已知输出+知识，调整输入。以改变输出。
了解过程的各个要素，通过改变不同的组合，形成新的创意。
1代码漏洞检测。
2合同条款审查。
3编剧。
4广告。
5创建世界观。
6多次沙盘模拟推演。

'''

# %% [markdown]
# 2 为ai提供具体的方法论（函数）

# %%
'''
方法论的边界：要明确它能够解决哪些问题，不能解决哪些问题。
方法论的好坏:1列出所有需要输入的要素信息。2了解正确的因果顺序。3为每个要素赋予正确的权重。

'''

# %% [markdown]
# 3 具体的书写方法

# %% [markdown]
# 1-4 宏观经济预测

# %% [markdown]
# 2-1 行业研究

# %% [markdown]
# 2-3 公司商业模式经营分析

# %%
'''
输入：公司名称

中间过程：
1产品模式：
2用户模式：
3推广模式;
4盈利模式：

输出：
一。公司简介：
1基本介绍。包括但不限于公司提供哪些服务，主要客户是谁，公司的使命，公司服务覆盖的范围，用户数量等。
2高管团队。
3发展历程。
'''

# %%
'''


归因分析需要明确两件事：
0了解整个项目的存在是为了解决什么问题，达到什么目的。
1了解整个项目的运作过程和机制，了解完整运作需要哪几个流程。如1，2，3，4，5个流程。一件事情是由那几个方面决定的。
2了解项目正常运行的结果，和项目非正常运行的结果。
3如果结果是非正常的，或者我想调整这个结果。怎么办，列出所有可能性，并逐一排查所有的流程，然后进行调整，直到出现我想要的状态。

'''

# %%
'''
1研究目的：
2整个过程和机制是怎样的，分为哪几个阶段或模块组成：
3这个现象产生的原因：
4经历一个完整的过程，会产生哪些结果：
5哪些阶段是最重要的，必不可少的：

'''

# %%
'''
波特五力分析
SWOT分析
价值链分析
'''

# %%
chat("gpt-3.5-turbo")
# Out:
# You: 请列举出类似于波特五力分析的一些思维框架
# Chatbot: 1. SWOT分析：SWOT分析是一种评估组织或个人优势、劣势、机会和威胁的方法。
#
# 2. 价值链分析：价值链分析是一种从供应商到客户的价值流程视角，识别企业内部活动的增值点。
#
# 3. 贝尔曼矩阵：贝尔曼矩阵是一种用于决策分析的工具，以评估不同决策对于特定目标的影响。
#
# 4. 解构分析：解构分析是一种研究任何事物的分析方法，基于分别分解和识别其各个组成部分和属性。
#
# 5. 惨案分析：惨案分析是一种管理工具，主要用于分析和识别组织内的问题，提出解决方案。
#
# 6. 竞争战略分析：竞争战略分析是一种评估组织的竞争优势和竞争力的方法，帮助企业实现与竞争对手的区别化。
#
# 7. 场景分析：场景分析是一种针对不同未来状态进行预测和规划的方法。
#
# 8. 新产品开发过程：新产品开发过程是一种基于市场需求和客户需求来规划、设计、开发和推广新产品的方法。
#
# 9. 成本收益分析：成本收益分析是一种衡量与排除不同方案和选择的成本和利益的方法。
#
# 10. 资源和能力分析：资源和能力分析是一种评估组织内部资源和能力以及与外部环境因素的互动关系的方法。
# You: 继续
# Chatbot: 11. 风险评估分析：风险评估分析是一种评估潜在风险和预测决策后果的方法。
#
# 12. 战略规划过程：战略规划过程是一种用于确定企业目标、策略和行动计划的方法。
#
# 13. 核心竞争力分析：核心竞争力分析是一种评估企业在竞争市场上保持优势的能力和因素的方法。
#
# 14. 协作分析：协作分析是一种评估和管理多个参与方互动的过程的方法。
#
# 15. 绩效评估：绩效评估是一种评估企业、部门、员工等绩效表现的方法。
#
# 16. 系统分析：系统分析是一种识别和评估复杂系统的方法，以开发更有效的解决方案。
#
# 17. 运营管理过程：运营管理过程是一种评估企业运营过程、管理模式和实践的方法。
#
# 18. 创新管理过程：创新管理过程是一种评估企业创新能力、实践和策略的方法。
#
# 19. 供应链分析：供应链分析是一种评估企业与供应商、制造商、分销商等合作伙伴之间的关系和交互作用的方法。
#
# ...

# %%
chat("gpt-3.5-turbo")
# Out:
# You: 常见的归因分析有哪些
# Chatbot: 常见的归因分析方法包括以下几种：
#
# 1. 实验设计归因分析：通过实验产生数据，将参与者随机分为不同的组别，比较不同组别间的结果差异，确定因果关系。
#
# 2. 时间序列归因分析：研究某个现象在时间序列上的变化趋势，分析影响该现象变化的因素，确定影响因素的重要程度。
#
# 3. 回归分析归因分析：使用回归模型分析因变量与自变量之间的关系，得出各自对因变量的贡献程度。
#
# 4. 多元因素分析归因分析：考虑多个因素对一个结果产生的影响，分析各个因素的相对重要程度。
#
# 5. 专家判断分析归因分析：依靠专家意见，根据其知识和经验对结果进行分析归因。
# You: bye

# %%
'''
1推理分析：根据原因推导出结果。（三段论：一个证据（置信度100%），一个推演过程（置信度80%），推论出一个结论。）

2归因分析：根据结果反推产生的原因。（一个确定的结果，多个可能的原因。）
行业不同，往往有不同的原因导致结果，所以归因分析在不同行业，差别也特别大。

归因分析需要明确两件事：
0了解整个项目的存在是为了解决什么问题，最终需要达到什么目的。要求ai按格式回答。
1了解整个项目的运作过程和机制，了解完整运作需要哪几个流程。如1，2，3，4，5个流程。一件事情是由那几个方面决定的。负责每一个流程的单位是谁。
2了解项目正常运行的结果，和项目非正常运行的结果。
3如果结果是非正常的，或者我想调整这个结果。怎么办，列出所有可能性，并逐一排查所有的流程，然后进行调整，直到出现我想要的状态。

'''

# %%
chat("gpt-3.5-turbo")
# Out:
# You: 你知道个人的价值可以分为几种吗
# Chatbot: 作为 AI 语言模型，我认为个人的价值可以从多个角度进行分类。以下是其中的一些可能分类方式：
#
# 1. 经济价值：指个人在市场上具有的价值，通常指个人的劳动力和所创造的财富。
#
# 2. 能力价值：指个人的技能、智力、领导才能和其他与工作相关的能力，这些能力通常可以通过学习、培训和实践获得。
#
# 3. 社会价值：指个人对社会的贡献和影响，如志愿者服务、慈善、创造性工作和其他付出时间和精力的活动。
#
# 4. 情感价值：指个人的周围人对于他/她的情感反应，如亲情、友情、爱情、尊重等等。
#
# 5. 个性价值：指个人的性格、兴趣、价值观、信仰、人品等个人特质，这些个人特质在社交场合中可以产生深刻的影响力。
#
# 这些分类方式并不是穷尽所有可能，而是展示了我们可能从不同的视角来考虑个人的价值。
# You: bye

# %%
'''
你是你个碳中和问题咨询专家。
我需要了解国际上为何会启动碳中和项目。
我需要了解，但不限于以下问题："
1碳中和的存在是为了解决什么问题，最终需要达到什么目的。
2碳中和整个项目运作的过程和机制，并列出需要哪几个流程。
3假如我希望通过碳交易获取利润，那么我应该从其中的哪几个流程切入。
"
请给出具有逻辑的回答，并且尽量一步一步思考。
'''

# %%
chat("gpt-3.5-turbo")
# Out:
# You: 你知道梦幻西游吗
# Chatbot: 我知道梦幻西游，它是一款由网易公司开发的传统式角色扮演游戏。该游戏使用中国神话和文化为背景，玩家可以扮演不同职业的角色，在游戏世界中探索、寻宝、战斗、冒险。梦幻西游至今已经推出了多个版本，拥有众多忠实玩家群体。
# You: 你如何看待梦幻西游的经济系统
# Chatbot: 梦幻西游的经济系统比较独特而复杂，它包含了多种货币和交易方式。虽然游戏中存在一些机制限制了虚拟货币的过度贬值，但是仍然存在一些玩家因为虚拟货币的贬值而感到不满。此外，一些玩家也会通过非法手段获取虚拟货币，导致了游戏经济的不稳定。总之，游戏经济的稳定和健康需要游戏运营方的有效管理和监控，同时也需要游戏玩家的自觉和自律。
# You: 你认为是哪些人在为这个游戏付费
# Chatbot: 梦幻西游游戏拥有广泛的玩家群体，其中付费玩家主要包括以下几类：
#
# 1. 游戏爱好者：这些人喜欢梦幻西游的游戏玩法、剧情和社交互动，愿意主动购买游戏道具、礼包和会员等。
#
# 2. 打工一族：这些人通常没有太多时间去游戏中获取游戏货币和物品，因此愿意通过付费获得游戏中的虚拟货币和装备。
#
# 3. 职业玩家：这些人把梦幻西游游戏作为收入来源，通过打怪、卖装备等方式获取游戏中的虚拟货币和装备，然后出售给其他玩家或向游戏公司兑换真实货币。
#
# 4. 粉丝或收藏家：这些人热爱梦幻西游游戏中的角色、场景等元素，喜欢购买游戏中的周边产品、收藏品等。
#
# 总之，梦幻西游游戏的付费玩家比较多元化，主要归结于游戏本身的品质和特色。
# You: 请你对梦幻西游的经济系统做出分析，目的是判断市场上的供需是否平衡，做出涨跌预测。
# Chatbot: 梦幻西游的虚拟经济系统较为复杂，包括游戏币、元宝等多种货币，交易方式也较为繁多，从交易行、拍卖行到玩家之间的交易都有涉及。根据一些经验规律以及统计数据来看，梦幻西游游戏中的经济系统，存在以下情况：
#
# 1. 存在部分物品与货币之间的欠缺现象，这导致了供需关系的不平衡。例如，某装备的需求量很高，而其与游戏币的换算比例又很低，导致了游戏币过度稀缺，而装备的价值会相应攀升，这时候装备的价格可能会出现短期内的上涨。
#
# ...
